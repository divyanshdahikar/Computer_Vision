# %%
import cv2

# %%
img = cv2.imread(r"D:\coding\OpenCV\WSCubeTech Open CV\IMGS\download.jpeg", 1)
# print(img)
print('shape of the image, ',img.shape)
img = cv2.resize(img, (500,600))
cv2.imshow('Original image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# shape of the image,  (960, 680, 3)

# %%
img = cv2.imread(r"D:\coding\OpenCV\WSCubeTech Open CV\IMGS\download.jpeg", -1)
# print(img)
print('shape of the image, ',img.shape)
img = cv2.resize(img, (500,600))
cv2.imshow('Original image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# shape of the image,  (960, 680, 3)

# %%
img = cv2.imread(r"D:\coding\OpenCV\WSCubeTech Open CV\IMGS\download.jpeg", 0)
# print(img)
print('shape of the image, ',img.shape)
img = cv2.resize(img, (500,600))
cv2.imshow('Original image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# shape of the image,  (960, 680)
