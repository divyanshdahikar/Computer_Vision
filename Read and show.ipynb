# %% [markdown]
# ## read show waitkey destroy

# %%
import cv2

# %%
img = cv2.imread(r"D:\coding\OpenCV\WSCubeTech Open CV\IMGS\ab6761610000e5eba8876245021fa0b7b5256b94.jpeg")
img1 = cv2.imread(r"D:\coding\OpenCV\WSCubeTech Open CV\IMGS\download.jpeg")
cv2.imshow('img 1',img)
cv2.imshow('img 2',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()
