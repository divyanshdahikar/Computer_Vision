# %%
import cv2

# %%
img = cv2.imread(r"D:\coding\OpenCV\WSCubeTech Open CV\IMGS\download.jpeg")
img = cv2.resize(img, (500,600))

img = cv2.line(img, (150,140), (350,120), (0,0,255), 3, 3)
cv2.imshow('Before img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# img, pt1, pt2, color[, thickness[, lineType

# %%
img = cv2.imread(r"D:\coding\OpenCV\WSCubeTech Open CV\IMGS\download.jpeg")
img = cv2.resize(img, (500,600))

img = cv2.rectangle(img, (130,50), (390,355), (0,0,255), 3, 3)
txt = cv2.putText(img, 'Radhe', (125,40), cv2.FONT_HERSHEY_COMPLEX, 1, (255,0,0), 2, cv2.LINE_4)
cv2.imshow('After img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# (img, text, org, fontFace, fontScale, color[, thickness[, lineType[, bottomLeftOrigin]]]
