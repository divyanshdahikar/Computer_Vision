# %%
import cv2

# %%
img1 = cv2.imread(r"D:\coding\OpenCV\WSCubeTech Open CV\IMGS\download.jpeg")
img2 = cv2.imread(r"D:\coding\OpenCV\WSCubeTech Open CV\IMGS\ab6761610000e5eba8876245021fa0b7b5256b94.jpeg")
img1 = cv2.resize(img1, (500,600))
img2 = cv2.resize(img2, (500,600))

img = cv2.addWeighted(img1, 1, img2, 0.5, 1)

cv2.imshow('Merged', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# (src1, alpha, src2, beta, gamma[, dst[, dtype]])
