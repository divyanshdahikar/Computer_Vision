# %%
import cv2

# %%
img = cv2.imread(r"D:\Art\download.jpeg")
img = cv2.resize(img, (600, 700))
crop = img[200:300,200:435]

cv2.imshow('Org img', img)
cv2.imshow('crop img', crop)
cv2.waitKey(0)
cv2.destroyAllWindows()
