# %%
import cv2
import numpy as np

# %%
img = cv2.imread(r"D:\coding\OpenCV\WSCubeTech Open CV\IMGS\download.jpeg")
img = cv2.resize(img, (500,600))

img = cv2.polylines(img, [np.array([[230,50], [380,130], [380,340], [200,355], [90,150]])], True, (255,0,0), 2, 4)
cv2.imshow('polygon', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# img, pts, isClosed, color[, thickness[, lineType[, shift]]])
